# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment

# %%
iris_data=pd.read_csv('iris.csv')
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset

# %%
iris_data.iloc[:, 0:4].apply(np.mean)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset

# %%
iris_data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# # Visualization 1

# %%
plt.figure(figsize=(6,4))
plt.scatter(iris_data['SL'], iris_data['Classification'], s=10, c='red', marker='^')
plt.title('Plot of SL vs Classification', fontsize=16)
plt.xlabel('SL')
plt.ylabel('Classification')
# Out:
# Text(0, 0.5, 'Classification')

# %% [markdown]
# # VIsualization 2

# %%
sns.pairplot(iris_data)

# %% [markdown]
# # Visualization 3

# %%
sns.boxplot(x='SW', y='Classification', data=iris_data)
plt.title('Boxplot of SW', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Boxplot of SW')

# %% [markdown]
# # Visualization 4

# %%
sns.heatmap(iris_data.corr(), annot=True)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])

# %% [markdown]
# # Visualization 5

# %%
sns.violinplot(x='PL', y='Classification', data=iris_data)
# Out:
# <AxesSubplot:xlabel='PL', ylabel='Classification'>
